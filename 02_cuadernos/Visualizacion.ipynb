# %%
# primero importamos las librerías que vamos a necesitar

import pandas as pd
import numpy as np

# estas son pa pintar
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# para el tiempo
import datetime

# %%
# Especificamos la ruta y el nombre del archivo CSV
ruta_archivo_csv = 'C:/Users/STF/Desktop/Ironhack/proyectos/ETL_project/01_data/tablas_SQL/shows.csv'

# Cargamos el archivo CSV en un DataFrame
df_shows_atrapalo = pd.read_csv(ruta_archivo_csv)

df_shows_atrapalo.head(20)
# Out:
#                                                  show  tipo  precio  duracion  \
# 0     La Hora y Media de El Club de la Comedia Madrid  show    22.0      90.0
# 1                    No cruces los brazos, David Cepo  show    17.0      75.0
# 2      Esto no es un show, con Galder Varas en Madrid  show    16.0     100.0
# 3           Buenrollistas - Víctor Parrado, en Madrid  show    14.0     100.0
# 4                      Intermitente - Carlos Martínez  show     7.9      60.0
# 5   Aguántame el cubata, que me da la risa - Juan ...  show    12.0      65.0
# 6                                 Oye Siri. Dime Joan  show    12.0      65.0
# 7   Solo para Parejas - Los mejores monólogos de M...  show    13.0      60.0
# 8                Ultrashow - Miguel Noguera en Madrid  show    14.9      75.0
# 9                Karim - Sólo para adultos, en Madrid  show    14.9      70.0
# 10                 Hij@s, el club de los malos padres  show    14.9      75.0
# ...

# %%
# primero importamos las librerías que vamos a necesitar

import pandas as pd
import numpy as np

# estas son pa pintar
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# para el tiempo
import datetime

# %%
# Especificamos la ruta y el nombre del archivo CSV
ruta_archivo_csv = 'C:/Users/STF/Desktop/Ironhack/proyectos/ELT_project/01_data/tablas_SQL/shows.csv'

# Cargamos el archivo CSV en un DataFrame
df_shows_atrapalo = pd.read_csv(ruta_archivo_csv)

df_shows_atrapalo.head(20)
# Out:
#                                                  show  tipo  precio  duracion  \
# 0     La Hora y Media de El Club de la Comedia Madrid  show    22.0      90.0
# 1                    No cruces los brazos, David Cepo  show    17.0      75.0
# 2      Esto no es un show, con Galder Varas en Madrid  show    16.0     100.0
# 3           Buenrollistas - Víctor Parrado, en Madrid  show    14.0     100.0
# 4                      Intermitente - Carlos Martínez  show     7.9      60.0
# 5   Aguántame el cubata, que me da la risa - Juan ...  show    12.0      65.0
# 6                                 Oye Siri. Dime Joan  show    12.0      65.0
# 7   Solo para Parejas - Los mejores monólogos de M...  show    13.0      60.0
# 8                Ultrashow - Miguel Noguera en Madrid  show    14.9      75.0
# 9                Karim - Sólo para adultos, en Madrid  show    14.9      70.0
# 10                 Hij@s, el club de los malos padres  show    14.9      75.0
# ...

# %%
df_shows_atrapalo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   show       212 non-null    object
#  1   tipo       212 non-null    object
#  2   precio     212 non-null    float64
#  3   duracion   212 non-null    float64
#  4   artista    212 non-null    object
#  5   local      212 non-null    object
#  6   nota       183 non-null    float64
#  7   opiniones  183 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 13.4+ KB

# %%
top_show_caros = df_shows_atrapalo.nlargest(10, 'precio')
top_show_caros
# Out:
#                                                 show  tipo  precio  duracion  \
# 0    La Hora y Media de El Club de la Comedia Madrid  show    22.0      90.0
# 11                                Lago - Comedy Club  show    21.0      60.0
# 16   David Guapo #Quenonosfrunjanlafiesta, en Madrid  show    20.0      70.0
# 142                El Unipersonal de Luciano Mellera  show    20.0      60.0
# 143       Momi Giardina - Cualquier cosa te llamamos  show    20.0      60.0
# 144              Racional - Pablo Molinari en Madrid  show    20.0      90.0
# 211                      Luis Gerónimo Abreu - Camas  show    20.0      75.0
# 13                        Miss Tupper Sex, en Madrid  show    18.0      90.0
# 82                             Fango - Rober Bodegas  show    18.0      60.0
# 1                   No cruces los brazos, David Cepo  show    17.0      75.0
#
#                  artista                               local  nota  opiniones
# ...

# %%
comparacion_duracion_precio = df_shows_atrapalo[['show', 'duracion', 'precio']]
comparacion_duracion_precio
# Out:
#                                                  show  duracion  precio
# 0     La Hora y Media de El Club de la Comedia Madrid      90.0    22.0
# 1                    No cruces los brazos, David Cepo      75.0    17.0
# 2      Esto no es un show, con Galder Varas en Madrid     100.0    16.0
# 3           Buenrollistas - Víctor Parrado, en Madrid     100.0    14.0
# 4                      Intermitente - Carlos Martínez      60.0     7.9
# ..                                                ...       ...     ...
# 207                               El Capi es mi cuñao      50.0    10.0
# 208                               ¡Se vienen Cositas!      60.0    10.0
# 209  Zapatiburger: 4 cómicos + 1 batería + 1 cantante      80.0     5.0
# 210                                             Tonta      70.0    10.0
# 211                       Luis Gerónimo Abreu - Camas      75.0    20.0
#
# [212 rows x 3 columns]

# %%
top_show_puntuacion = df_shows_atrapalo.nlargest(10, 'nota')
top_show_puntuacion
# Out:
#                                           show  tipo  precio  duracion  \
# 49              Alicia Lobo - Hola, no me líes  show     9.6      70.0
# 147  Alex Clavero y Karim - Noche de Monólogos  show    15.0      70.0
# 157                                       Tabú  show     7.5      70.0
# 160   Alberto Graupera.- No le busques sentido  show    12.0      70.0
# 164             Quique Matilla - Vastante vien  show    12.0      75.0
# 172                    Ganso: un show de Edu J  show    10.0      70.0
# 180                La vida me importa un huevo  show    10.0      75.0
# 185                                 Capilladas  show    10.0      60.0
# 188                     Sin Pelos En La Lengua  show     5.0      60.0
# 194                   Ganso: el show de Edu J.  show     9.0      70.0
#
#               artista                                  local  nota  opiniones
# 49        alicia lobo                      Cinesa Fuencarral  10.0       20.0
# ...

# %%
top_show_opiniones = df_shows_atrapalo.nlargest(10, 'opiniones')
top_show_opiniones
# Out:
#                                                 show  tipo  precio  duracion  \
# 68      Monólogos en la Chocita del Loro Carabanchel  show    10.0      80.0
# 69      Monólogos en la Chocita del Loro Carabanchel  show    10.0      80.0
# 0    La Hora y Media de El Club de la Comedia Madrid  show    22.0      90.0
# 16   David Guapo #Quenonosfrunjanlafiesta, en Madrid  show    20.0      70.0
# 18  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 19  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 20  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 21  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 22  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 23  Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
#
#                     artista                                     local  nota  \
# ...

# %%
# Filtrar los shows con más de 1000 comentarios
shows_con_mas_comentarios = df_shows_atrapalo[df_shows_atrapalo['opiniones'] > 1000]

# Obtener el top de shows con más puntuación de aquellos que tienen más de 20 comentarios
top_show_puntuacion_1000 = shows_con_mas_comentarios.nlargest(10, 'nota')
top_show_puntuacion_1000
# Out:
#                                                  show  tipo  precio  duracion  \
# 7   Solo para Parejas - Los mejores monólogos de M...  show    13.0      60.0
# 9                Karim - Sólo para adultos, en Madrid  show    14.9      70.0
# 31      Es mi palabra contra la mía - Luís Piedrahita  show    15.2      90.0
# 13                         Miss Tupper Sex, en Madrid  show    18.0      90.0
# 18   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 19   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 20   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 21   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 22   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
# 23   Monólogos de humor - Chocita del Loro Av. Brasil  show    11.0      65.0
#
#                     artista                                     local  nota  \
# ...

# %%
# Filtrar los shows con más de 20 comentarios y que no contengan "chocita del loro" en la columna 'local'
shows_filtrados = df_shows_atrapalo[(df_shows_atrapalo['opiniones'] > 1000) & (~df_shows_atrapalo['local'].str.contains('chocita del loro', case=False))]

# Obtener el top de shows con más puntuación de aquellos que cumplen con los filtros
top_show_puntuacion_no_chocita = shows_filtrados.nlargest(10, 'nota')
top_show_puntuacion_no_chocita
# Out:
#                                                   show  tipo  precio  \
# 7    Solo para Parejas - Los mejores monólogos de M...  show    13.0
# 9                 Karim - Sólo para adultos, en Madrid  show    14.9
# 31       Es mi palabra contra la mía - Luís Piedrahita  show    15.2
# 13                          Miss Tupper Sex, en Madrid  show    18.0
# 33        Tinder Sorpresa - Andreu Casanova, en Madrid  show    16.0
# 102               Nacho García: Estoy mayor, en Madrid  show    10.0
# 16     David Guapo #Quenonosfrunjanlafiesta, en Madrid  show    20.0
# 0      La Hora y Media de El Club de la Comedia Madrid  show    22.0
#
#      duracion          artista                               local  nota  \
# 7        60.0   alex salaberri                   Estación Malasaña   9.9
# 9        70.0            karim                     Teatros Luchana   9.4
# 31       90.0  luís piedrahita               Teatro Reina Victoria   9.4
# ...
